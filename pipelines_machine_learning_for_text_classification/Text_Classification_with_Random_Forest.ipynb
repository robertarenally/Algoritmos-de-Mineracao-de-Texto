# %%
import pandas as pd

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_20ng.csv', sep=';')

# %%
resultados
# Out:
#    Unnamed: 0  mean_fit_time  mean_score_time  mean_test_accuracy  \
# 0           0       7.044274         0.907396            0.686671
# 1           1      11.096615         0.957112            0.773908
# 2           2      15.294493         0.999531            0.793177
# 3           3      19.704565         1.061035            0.814831
# 4           4      23.982813         1.075483            0.819074
# 5           5      28.455911         1.133486            0.828443
# 6           6      32.506435         1.164210            0.835337
# 7           7      36.793369         1.206817            0.834718
# 8           8      41.445621         1.239698            0.837281
# 9           9      44.877218         1.238852            0.840817
#
#    mean_test_f1_macro  mean_test_f1_micro  mean_train_accuracy  \
# 0            0.680871            0.686671             0.997967
# 1            0.767158            0.773908             0.999853
# 2            0.786681            0.793177             0.999892
# 3            0.807405            0.814831             0.999912
# 4            0.813310            0.819074             0.999912
# 5            0.822053            0.828443             0.999921
# 6            0.829914            0.835337             0.999921
# 7            0.829192            0.834718             0.999921
# 8            0.831834            0.837281             0.999921
# 9            0.835205            0.840817             0.999921
#
#    mean_train_f1_macro  mean_train_f1_micro  param_clf__n_estimators  \
# 0             0.997925             0.997967                       10
# 1             0.999856             0.999853                       20
# 2             0.999897             0.999892                       30
# 3             0.999916             0.999912                       40
# 4             0.999916             0.999912                       50
# 5             0.999925             0.999921                       60
# 6             0.999925             0.999921                       70
# 7             0.999925             0.999921                       80
# 8             0.999925             0.999921                       90
# 9             0.999925             0.999921                      100
#
#           ...         split9_train_f1_macro  split9_train_f1_micro  \
# 0         ...                      0.998209               0.998234
# 1         ...                      0.999907               0.999902
# 2         ...                      0.999812               0.999804
# 3         ...                      0.999907               0.999902
# 4         ...                      0.999907               0.999902
# 5         ...                      0.999907               0.999902
# 6         ...                      0.999907               0.999902
# 7         ...                      0.999907               0.999902
# 8         ...                      0.999907               0.999902
# 9         ...                      0.999907               0.999902
#
#    std_fit_time  std_score_time  std_test_accuracy  std_test_f1_macro  \
# 0      0.154431        0.039878           0.013849           0.012970
# 1      0.224660        0.045499           0.011681           0.010487
# 2      0.361067        0.054422           0.008666           0.007686
# 3      0.517234        0.043446           0.007599           0.008376
# 4      0.585683        0.068255           0.009160           0.009470
# 5      0.875560        0.061481           0.008672           0.008407
# 6      0.952913        0.067137           0.008148           0.007958
# 7      1.100794        0.055628           0.008359           0.007591
# 8      1.280781        0.054269           0.013904           0.013529
# 9      2.097691        0.105224           0.009031           0.009255
#
#    std_test_f1_micro  std_train_accuracy  std_train_f1_macro  \
# 0           0.013849            0.000187            0.000182
# 1           0.011681            0.000079            0.000078
# 2           0.008666            0.000053            0.000051
# 3           0.007599            0.000029            0.000028
# 4           0.009160            0.000053            0.000051
# 5           0.008672            0.000039            0.000037
# 6           0.008148            0.000039            0.000037
# 7           0.008359            0.000039            0.000037
# 8           0.013904            0.000039            0.000037
# 9           0.009031            0.000039            0.000037
#
#    std_train_f1_micro
# 0            0.000187
# 1            0.000079
# 2            0.000053
# 3            0.000029
# 4            0.000053
# 5            0.000039
# 6            0.000039
# 7            0.000039
# 8            0.000039
# 9            0.000039
#
# [10 rows x 82 columns]

# %%
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_20ng = means_test
# Out:
# mean_test_accuracy: 0.686671 (0.013849) - mean_train_accuracy: 0.997967 (0.013849) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.773908 (0.011681) - mean_train_accuracy: 0.999853 (0.011681) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.793177 (0.008666) - mean_train_accuracy: 0.999892 (0.008666) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.814831 (0.007599) - mean_train_accuracy: 0.999912 (0.007599) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.819074 (0.009160) - mean_train_accuracy: 0.999912 (0.009160) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.828443 (0.008672) - mean_train_accuracy: 0.999921 (0.008672) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.835337 (0.008148) - mean_train_accuracy: 0.999921 (0.008148) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.834718 (0.008359) - mean_train_accuracy: 0.999921 (0.008359) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.837281 (0.013904) - mean_train_accuracy: 0.999921 (0.013904) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.840817 (0.009031) - mean_train_accuracy: 0.999921 (0.009031) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_classic3.csv', sep=';')

# %%
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_classic3 = means_test
# Out:
# mean_test_accuracy: 0.876251 (0.015642) - mean_train_accuracy: 0.997103 (0.015642) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.910078 (0.010163) - mean_train_accuracy: 0.999577 (0.010163) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.919098 (0.013156) - mean_train_accuracy: 0.999937 (0.013156) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.925300 (0.008963) - mean_train_accuracy: 0.999984 (0.008963) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.926991 (0.010128) - mean_train_accuracy: 1.000000 (0.010128) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.930374 (0.008851) - mean_train_accuracy: 0.999984 (0.008851) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.931783 (0.009929) - mean_train_accuracy: 1.000000 (0.009929) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.932065 (0.009549) - mean_train_accuracy: 0.999984 (0.009549) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.933615 (0.011478) - mean_train_accuracy: 1.000000 (0.011478) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.933615 (0.009273) - mean_train_accuracy: 1.000000 (0.009273) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_CSTR.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_cstr = means_test
# Out:
# mean_test_accuracy: 0.709030 (0.091574) - mean_train_accuracy: 0.968405 (0.091574) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.709030 (0.077674) - mean_train_accuracy: 0.976973 (0.077674) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.745819 (0.068016) - mean_train_accuracy: 0.978447 (0.068016) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.762542 (0.054832) - mean_train_accuracy: 0.978820 (0.054832) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.769231 (0.037413) - mean_train_accuracy: 0.978820 (0.037413) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.769231 (0.063261) - mean_train_accuracy: 0.978820 (0.063261) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.762542 (0.081352) - mean_train_accuracy: 0.978820 (0.081352) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.745819 (0.054903) - mean_train_accuracy: 0.978820 (0.054903) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.759197 (0.072772) - mean_train_accuracy: 0.978820 (0.072772) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.762542 (0.049925) - mean_train_accuracy: 0.978820 (0.049925) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_IrishEconomicSentiment.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_IrishEconomicSentiment = means_test
# Out:
# mean_test_accuracy: 0.541566 (0.035660) - mean_train_accuracy: 0.988554 (0.035660) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.592169 (0.037673) - mean_train_accuracy: 0.998528 (0.037673) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.600000 (0.022867) - mean_train_accuracy: 1.000000 (0.022867) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.623494 (0.027431) - mean_train_accuracy: 1.000000 (0.027431) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.631928 (0.029130) - mean_train_accuracy: 1.000000 (0.029130) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.633735 (0.028451) - mean_train_accuracy: 1.000000 (0.028451) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.631928 (0.029893) - mean_train_accuracy: 1.000000 (0.029893) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.644578 (0.022072) - mean_train_accuracy: 1.000000 (0.022072) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.636747 (0.013301) - mean_train_accuracy: 1.000000 (0.013301) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.637952 (0.024975) - mean_train_accuracy: 1.000000 (0.024975) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_multi-domain-sentiment.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_multi_domain_sentiment = means_test
# Out:
# mean_test_accuracy: 0.730000 (0.016761) - mean_train_accuracy: 0.992417 (0.016761) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.766000 (0.018052) - mean_train_accuracy: 0.999306 (0.018052) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.789000 (0.013391) - mean_train_accuracy: 0.999917 (0.013391) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.800375 (0.016404) - mean_train_accuracy: 0.999986 (0.016404) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.805625 (0.014909) - mean_train_accuracy: 0.999986 (0.014909) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.809375 (0.017395) - mean_train_accuracy: 1.000000 (0.017395) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.816375 (0.015697) - mean_train_accuracy: 1.000000 (0.015697) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.818750 (0.014186) - mean_train_accuracy: 1.000000 (0.014186) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.821875 (0.015383) - mean_train_accuracy: 1.000000 (0.015383) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.823875 (0.015756) - mean_train_accuracy: 1.000000 (0.015756) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_NSF.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_NSF = means_test
# Out:
# mean_test_accuracy: 0.696788 (0.016216) - mean_train_accuracy: 0.993897 (0.016216) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.730901 (0.007329) - mean_train_accuracy: 0.999082 (0.007329) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.738027 (0.009505) - mean_train_accuracy: 0.999694 (0.009505) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.745344 (0.010125) - mean_train_accuracy: 0.999905 (0.010125) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.745724 (0.010018) - mean_train_accuracy: 0.999947 (0.010018) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.750570 (0.013692) - mean_train_accuracy: 0.999989 (0.013692) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.752946 (0.010359) - mean_train_accuracy: 0.999989 (0.010359) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.752376 (0.011154) - mean_train_accuracy: 1.000000 (0.011154) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.752756 (0.007890) - mean_train_accuracy: 1.000000 (0.007890) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.753516 (0.010897) - mean_train_accuracy: 1.000000 (0.010897) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_Opinosis-Parsed.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_Opinosis_Parsed = means_test
# Out:
# mean_test_accuracy: 0.567601 (0.023432) - mean_train_accuracy: 0.920654 (0.023432) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.587579 (0.019362) - mean_train_accuracy: 0.924991 (0.019362) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.589438 (0.016743) - mean_train_accuracy: 0.925334 (0.016743) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.592380 (0.016766) - mean_train_accuracy: 0.925369 (0.016766) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.601827 (0.020870) - mean_train_accuracy: 0.925438 (0.020870) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.603376 (0.015608) - mean_train_accuracy: 0.925420 (0.015608) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.602602 (0.020982) - mean_train_accuracy: 0.925438 (0.020982) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.607867 (0.014145) - mean_train_accuracy: 0.925438 (0.014145) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.602912 (0.019369) - mean_train_accuracy: 0.925438 (0.019369) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.600898 (0.016064) - mean_train_accuracy: 0.925438 (0.016064) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_re8.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_re8 = means_test
# Out:
# mean_test_accuracy: 0.902789 (0.010013) - mean_train_accuracy: 0.997350 (0.010013) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.918556 (0.009419) - mean_train_accuracy: 0.999218 (0.009419) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.926244 (0.008297) - mean_train_accuracy: 0.999421 (0.008297) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.928590 (0.005987) - mean_train_accuracy: 0.999493 (0.005987) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.928199 (0.008102) - mean_train_accuracy: 0.999493 (0.008102) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.929763 (0.008659) - mean_train_accuracy: 0.999508 (0.008659) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.929893 (0.004363) - mean_train_accuracy: 0.999522 (0.004363) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.931717 (0.006503) - mean_train_accuracy: 0.999522 (0.006503) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.931327 (0.007781) - mean_train_accuracy: 0.999522 (0.007781) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.932760 (0.006879) - mean_train_accuracy: 0.999522 (0.006879) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_review_polarity.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_review_polarity = means_test
# Out:
# mean_test_accuracy: 0.685500 (0.023071) - mean_train_accuracy: 0.992222 (0.023071) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.713500 (0.023564) - mean_train_accuracy: 0.999833 (0.023564) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.736500 (0.019500) - mean_train_accuracy: 1.000000 (0.019500) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.758500 (0.042074) - mean_train_accuracy: 1.000000 (0.042074) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.761500 (0.026368) - mean_train_accuracy: 1.000000 (0.026368) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.766500 (0.024500) - mean_train_accuracy: 1.000000 (0.024500) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.779000 (0.019209) - mean_train_accuracy: 1.000000 (0.019209) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.784000 (0.029816) - mean_train_accuracy: 1.000000 (0.029816) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.786000 (0.028705) - mean_train_accuracy: 1.000000 (0.028705) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.782000 (0.022825) - mean_train_accuracy: 1.000000 (0.022825) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_Reviews.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_reviews = means_test
# Out:
# mean_test_accuracy: 0.899484 (0.014183) - mean_train_accuracy: 0.997925 (0.014183) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.930204 (0.011514) - mean_train_accuracy: 0.999645 (0.011514) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.934136 (0.010745) - mean_train_accuracy: 0.999891 (0.010745) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.938068 (0.009909) - mean_train_accuracy: 0.999918 (0.009909) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.941263 (0.008211) - mean_train_accuracy: 1.000000 (0.008211) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.947161 (0.011439) - mean_train_accuracy: 1.000000 (0.011439) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.943229 (0.010928) - mean_train_accuracy: 1.000000 (0.010928) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.944704 (0.012945) - mean_train_accuracy: 1.000000 (0.012945) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.943967 (0.011928) - mean_train_accuracy: 1.000000 (0.011928) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.943721 (0.011134) - mean_train_accuracy: 1.000000 (0.011134) with: "{'clf__n_estimators': 100}"

# %%
resultados = pd.read_csv('resultado_pipeline_random_forest_Syskillwebert-Parsed.csv', sep=';')
means_test = resultados['mean_test_accuracy']
std_test_acuracy = resultados['std_test_accuracy']
means_train = resultados['mean_train_accuracy']
std_train_acuracy = resultados['std_test_accuracy']
params = resultados['params']

for test, stdev_test, train, stdev_train, param in zip(means_test, std_test_acuracy, means_train, std_train_acuracy, params):
    print("mean_test_accuracy: %f (%f) - mean_train_accuracy: %f (%f) with: %r" %(test, stdev_test, train, stdev_train, param))
    
test_Syskillwebert_Parsed = means_test
# Out:
# mean_test_accuracy: 0.838323 (0.043439) - mean_train_accuracy: 0.990684 (0.043439) with: "{'clf__n_estimators': 10}"
# mean_test_accuracy: 0.892216 (0.068149) - mean_train_accuracy: 0.994011 (0.068149) with: "{'clf__n_estimators': 20}"
# mean_test_accuracy: 0.874251 (0.041116) - mean_train_accuracy: 0.994340 (0.041116) with: "{'clf__n_estimators': 30}"
# mean_test_accuracy: 0.901198 (0.044029) - mean_train_accuracy: 0.994344 (0.044029) with: "{'clf__n_estimators': 40}"
# mean_test_accuracy: 0.907186 (0.037350) - mean_train_accuracy: 0.994675 (0.037350) with: "{'clf__n_estimators': 50}"
# mean_test_accuracy: 0.898204 (0.050649) - mean_train_accuracy: 0.994675 (0.050649) with: "{'clf__n_estimators': 60}"
# mean_test_accuracy: 0.919162 (0.034427) - mean_train_accuracy: 0.994675 (0.034427) with: "{'clf__n_estimators': 70}"
# mean_test_accuracy: 0.919162 (0.041087) - mean_train_accuracy: 0.994675 (0.041087) with: "{'clf__n_estimators': 80}"
# mean_test_accuracy: 0.913174 (0.043577) - mean_train_accuracy: 0.994675 (0.043577) with: "{'clf__n_estimators': 90}"
# mean_test_accuracy: 0.913174 (0.027798) - mean_train_accuracy: 0.994675 (0.027798) with: "{'clf__n_estimators': 100}"

# %%
list_of_tuples = list(zip(params, test_20ng, test_classic3, test_cstr, test_IrishEconomicSentiment, test_multi_domain_sentiment, test_NSF, test_Opinosis_Parsed, test_re8, test_review_polarity, test_reviews, test_Syskillwebert_Parsed)) 
df = pd.DataFrame(list_of_tuples, columns = ["params", "20newsGroup", "Classic3", "CSTR", "Irish_Economic_Sentiment", "Multi_Domain_Sentiment","NSF","Opinosis-Parsed", "re8", "Review_Polarity","Reviews","SyskillWelbert-Parsed"])
df.to_csv("random_forest.csv")
